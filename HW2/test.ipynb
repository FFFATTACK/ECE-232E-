# %%
library(igraph)

# %%
g<-barabasi.game(8,m=3,directed=F)
plot(g)
# Out:
# Plot with title ""

# %%
highlight<-incident(g,2)
color_vec<-fastgreedy.community(g)
E(g)[highlight]$color = "red"
plot(g,vertex.color=color_vec$membership,vertex.label=NA)
# Out:
# Plot with title ""

# %%
i=3;
function{
    i=2;   
}
# Out:
# [1] 3

# %%
a<-x+1
a
# Out:
# [1] 4
